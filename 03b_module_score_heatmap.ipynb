# %%
library(ComplexHeatmap)
library(circlize)
library(RColorBrewer)

# %%
liwang_module <- read.table("/sc/arion/projects/roussp01a/liting/Olf/data/liwang_OSN_modulescore.txt",sep=',',header = T, row.names = 1, check.names = F)
pro_cells <- colnames(liwang_module)[grepl('RG|Immature|Newborn|IPC',colnames(liwang_module))]
liwang_module_prog <- liwang_module[,pro_cells]

# %%
scale_liwang_module <- t(apply(liwang_module,1, scale))
colnames(scale_liwang_module) <- colnames(liwang_module)
scale_liwang_module_prog <- scale_liwang_module[,pro_cells]

# %%
ComplexHeatmap::draw(Heatmap(
    scale_liwang_module,    
    cluster_rows = F,
    cluster_columns              = T,
    name='Module score',
    col= colorRamp2(seq(from=min(scale_liwang_module),to=max(scale_liwang_module),length=9),rev(brewer.pal(11, "RdBu")[c(-1,-11)])),
    row_gap = unit(c(2.5), "mm"),
    show_row_names               = T,
    show_column_names            = T,
    show_row_dend = T,

))
dev.print(pdf, file='/sc/arion/projects/roussp01a/liting/Olf/figures/liwang_OSN_Scaled_modulescore.pdf')
# Out:
# pdf
#   2
# plot without title

# %%
ComplexHeatmap::draw(Heatmap(
    liwang_module,    
    cluster_rows = F,
    cluster_columns              = T,
    name='Module score',
    col= colorRamp2(seq(from=min(liwang_module),to=max(liwang_module),length=9),rev(brewer.pal(11, "RdBu")[c(-1,-11)])),
    row_gap = unit(c(2.5), "mm"),
    show_row_names               = T,
    show_column_names            = T,
    show_row_dend = T,

  
))

dev.print(pdf, file='/sc/arion/projects/roussp01a/liting/Olf/figures/liwang_OSN_modulescore.pdf')
# Out:
# Warning message:
# “The input is a data frame-like object, convert it to a matrix.”
# pdf
#   2
# plot without title

# %%
ComplexHeatmap::draw(Heatmap(
    scale_liwang_module_prog,    
    cluster_rows = F,
    cluster_columns              = T,
    name='Module score',
    col= colorRamp2(seq(from=min(scale_liwang_module_prog),to=max(scale_liwang_module_prog),length=9),rev(brewer.pal(11, "RdBu")[c(-1,-11)])),
    row_gap = unit(c(2.5), "mm"),
    show_row_names               = T,
    show_column_names            = T,
    show_row_dend = T,

  
))
dev.print(pdf, file='/sc/arion/projects/roussp01a/liting/Olf/figures/scale_liwang_Prog_OSN_modulescore.pdf')
# Out:
# pdf
#   2
# plot without title

# %%
ComplexHeatmap::draw(Heatmap(
    liwang_module_prog,    
    cluster_rows = F,
    cluster_columns              = T,
    name='Module score',
    col= colorRamp2(seq(from=min(liwang_module_prog),to=max(liwang_module_prog),length=9),rev(brewer.pal(11, "RdBu")[c(-1,-11)])),
    row_gap = unit(c(2.5), "mm"),
    show_row_names               = T,
    show_column_names            = T,
    show_row_dend = T,

  
))
dev.print(pdf, file='/sc/arion/projects/roussp01a/liting/Olf/figures/liwang_Prog_OSN_modulescore.pdf')
# Out:
# Warning message:
# “The input is a data frame-like object, convert it to a matrix.”
# pdf
#   2
# plot without title

# %%
lister_module <- read.table("/sc/arion/projects/roussp01a/liting/Olf/data/lister_OSN_modulescore.txt",sep=',',header = T, row.names = 1, check.names = F)

# %%
ComplexHeatmap::draw(Heatmap(
    lister_module,    
    cluster_rows = F,
    cluster_columns              = T,
    name='Module score',
    col= colorRamp2(seq(from=min(lister_module),to=max(lister_module),length=9),rev(brewer.pal(11, "RdBu")[c(-1,-11)])),
    row_gap = unit(c(2.5), "mm"),
    show_row_names               = T,
    show_column_names            = T,
    show_row_dend = T,

  
))
dev.print(pdf, file='/sc/arion/projects/roussp01a/liting/Olf/figures/lister_OSN_modulescore.pdf')
# Out:
# Warning message:
# “The input is a data frame-like object, convert it to a matrix.”
# pdf
#   2
# plot without title

# %%
scale_lister_module <- t(apply(lister_module,1, scale))
colnames(scale_lister_module) <- colnames(lister_module)


ComplexHeatmap::draw(Heatmap(
    scale_lister_module,    
    cluster_rows = F,
    cluster_columns              = T,
    name='Module score',
    col= colorRamp2(seq(from=min(scale_lister_module),to=max(scale_lister_module),length=9),rev(brewer.pal(11, "RdBu")[c(-1,-11)])),
    row_gap = unit(c(2.5), "mm"),
    show_row_names               = T,
    show_column_names            = T,
    show_row_dend = T,

  
))
dev.print(pdf, file='/sc/arion/projects/roussp01a/liting/Olf/figures/lister_OSN_Scalemodulescore.pdf')
# Out:
# pdf
#   2
# plot without title
